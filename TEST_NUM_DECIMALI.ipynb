# %% [markdown]
# # PER IL CORRETTO FUNZIONAMENTO DEL CODICE:

# %% [markdown]
# # Librerie usate

# %%
import time
from numpy.random import seed
from numpy.random import randint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Visualizazione Dataset

# %%
data = pd.read_csv("dataset.csv")
data
# Out:
#        premio_effet_anno_incorso  eta_polizza bonus_malus
# 0                     1951.40000            3          11
# 1                      265.46190            9          1F
# 2                      276.84340           10          1G
# 3                      289.58118            6          1H
# 4                      173.86400           24          1F
# ...                          ...          ...         ...
# 45386                  239.41000           32          1G
# 45387                  250.79000           33          1H
# 45388                  350.39570            8          1F
# 45389                  364.18740            9          1G
# 45390                  382.51016            6          1H
#
# [45391 rows x 3 columns]

# %%
data_2 = pd.read_csv("dataset.csv")
data_2.sort_values(by=['premio_effet_anno_incorso'], ascending = True, inplace = True)
data_2
# Out:
#        premio_effet_anno_incorso  eta_polizza bonus_malus
# 35455                    19.2700            1          14
# 4411                     41.1400            5          10
# 17046                    42.5493           14          1C
# 4412                     48.5600            6          09
# 4413                     50.4300            7          08
# ...                          ...          ...         ...
# 41079                  2951.5732            2          15
# 41078                  2954.4417            1          15
# 7250                 502125.0000            3          11
# 43298                632125.0000            2          12
# 6709                 632125.0000            7          05
#
# [45391 rows x 3 columns]

# %% [markdown]
# # FUNZIONI

# %% [markdown]
# funzioni algoritmi

# %%
def insertionSort(arr):
    # Scorri da 1 a  len(arr)#
    for i in range(1, len(arr)):
        
  
        key = arr[i]
  
        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key
        
def bubbleSort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n-1):
    # range(n) also work but outer loop will repeat one time more than needed.
        # Last i elements are already in place
        for j in range(0, n-i-1):
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
                
def quickSort(array):
    length = len(array)
    
    if length <= 1:
        return array
    
    if length == 2:
        if array[0] > array[1]:
            return [array[1], array[0]]
        else:
            return array
        
    else:
        pivot = np.random.randint(0, length)
        small = []
        large = []
        
        for element in array:
            if element < array[pivot]:
                small.append(element)
            elif element > array[pivot]:
                large.append(element)
                
        #if not small:
            #return [array[pivot]] + quickSort(large)
        #elif not large:
            #return quickSort(small) + [array[pivot]]
        #else:
            #return (quickSort(small)
                    #+ [array[pivot]]
                    #+ quickSort(large))

def mergeSort(myList):
    if len(myList) > 1:
        mid = len(myList) // 2
        left = myList[:mid]
        right = myList[mid:]

        # Recursive call on each half
        mergeSort(left)
        mergeSort(right)

        # Two iterators for traversing the two halves
        i = 0
        j = 0

        # Iterator for the main list
        k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
              # The value from the left half has been used
              myList[k] = left[i]
              # Move the iterator forward
              i += 1
            else:
                myList[k] = right[j]
                j += 1
            # Move to the next slot
            k += 1
            #per tutti i resto dei numeri 
        while i < len(left):
            myList[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            myList[k]=right[j]
            j += 1
            k += 1
            
def max_heapify(array, i):
    l = (i+1) * 2 - 1
    r = (i+1) * 2
    length = len(array)
    if l < length and array[l] > array[i]:
        largest = l
    else: 
        largest = i
    
    if r < length and array[r] > array[largest]:
        largest = r
        
    if largest != i:
        largest_value = array[largest]
        array[largest] = array[i]
        array[i] = largest_value
        max_heapify(array, largest)
        
    return array

def build_max_heap(array):
    length = len(array)
    for i in range(length//2, -1, -1):
        max_heapify(array, i)
    return array

def heapSort(array):
    length = len(array)
    array = build_max_heap(array)
    for i in range(length-1, 0, -1):
        largest = array[0]
        array[0] = array[i]
        array[i] = largest
        max_heapify(array[:i], 0)
        
    return array

# %% [markdown]
# # Dimostrazione ordinamento

# %%
xmerge = data["premio_effet_anno_incorso"] 
_subset = xmerge[0 : 2000]
arr = np.array(_subset)
list_merge= arr.tolist()

mergeSort(list_merge)
record_merge = []
for i in range(len(list_merge)):
    record_merge.append("%s" %list_merge[i])
with open("record_ordinati_merge_DECIMALI.txt", "w") as file:
    file.write(str(record_merge))

# %%
xheap = data["premio_effet_anno_incorso"] 
_subset = xheap[0 : 2000]
arr = np.array(_subset)
list_heap= arr.tolist()

heapSort(list_heap)
record_heap = []
for i in range(len(list_heap)):
    record_heap.append("%s" %list_heap[i])
with open("record_ordinati_heap_DECIMALI.txt", "w") as file:
    file.write(str(record_heap))

# %%
xquick = data["premio_effet_anno_incorso"] 
_subset = xquick[0 : 2000]
arr = np.array(_subset)
list_quick= arr.tolist()

quickSort(list_quick)
record_quick = []
for i in range(len(list_quick)):
    record_quick.append("%s" %list_quick[i])
with open("record_ordinati_quick_DECIMALI.txt", "w") as file:
    file.write(str(record_quick))

# %%
xins = data["premio_effet_anno_incorso"] 
_subset = xins[0 : 2000]
arr = np.array(_subset)
list_ins= arr.tolist()

insertionSort(list_ins)
record_ins = []
for i in range(len(list_ins)):
    record_ins.append("%s" %list_ins[i])
with open("record_ordinati_insertion_DECIMALI.txt", "w") as file:
    file.write(str(record_ins))

# %%
xbubble = data["premio_effet_anno_incorso"] 
_subset = xbubble[0 : 2000]
arr = np.array(_subset)
list_bubble= arr.tolist()

bubbleSort(list_bubble)
record_bubble = []
for i in range(len(list_bubble)):
    record_bubble.append("%s" %list_bubble[i])
with open("record_ordinati_bubble_DECIMALI.txt", "w") as file:
    file.write(str(record_bubble))

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi

# %% [markdown]
# ## Record non ordinati su numeri interi
# ### test su 45mila elementi

# %%
#MERGE
elements_merge = list()
times_merge = list()
for i in range(1, 6):
  
    xmerge = data['premio_effet_anno_incorso'] 
    _subset = xmerge[0 : 9000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge.append(len(list_merge))
    times_merge.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by MergeSort in  0.03889632225036621
# 18000 Elements Sorted by MergeSort in  0.08510637283325195
# 27000 Elements Sorted by MergeSort in  0.12514662742614746
# 36000 Elements Sorted by MergeSort in  0.17406153678894043
# 45000 Elements Sorted by MergeSort in  0.22134852409362793

# %%
#BUBBLE
elements_bubble = list()
times_bubble = list()
for i in range(1, 6):
  
    xbubble = data['premio_effet_anno_incorso'] 
    _subset = xbubble[0 : 9000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble.append(len(list_bubble))
    times_bubble.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by BubbleSort in  6.771959543228149
# 18000 Elements Sorted by BubbleSort in  27.427451133728027
# 27000 Elements Sorted by BubbleSort in  60.31181740760803
# 36000 Elements Sorted by BubbleSort in  111.4410891532898
# 45000 Elements Sorted by BubbleSort in  172.86607480049133

# %%
#INSERTION
elements_inse = list()
times_inse = list()
for i in range(1, 6):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse.append(len(list_inse))
    times_inse.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse, times_inse, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by InsertionSort in  3.025125741958618
# 18000 Elements Sorted by InsertionSort in  12.252323627471924
# 27000 Elements Sorted by InsertionSort in  26.718649864196777
# 36000 Elements Sorted by InsertionSort in  48.2902991771698
# 45000 Elements Sorted by InsertionSort in  72.03614115715027

# %%
#QUICKSORT
elements_quick = list()
times_quick = list()
for i in range(1, 6):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_quick = arr.tolist()
    start = time.time()
    quickSort(list_quick)
    end = time.time()
  
    print(len(list_quick), "Elements Sorted by QuickSort in ", end-start)
    elements_quick.append(len(list_quick))
    times_quick.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick, times_quick, label ='QuickSort',color = 'brown')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by QuickSort in  0.031468868255615234
# 18000 Elements Sorted by QuickSort in  0.05983877182006836
# 27000 Elements Sorted by QuickSort in  0.0857686996459961
# 36000 Elements Sorted by QuickSort in  0.12075328826904297
# 45000 Elements Sorted by QuickSort in  0.14757537841796875

# %%
#HEAP
elements_heap = list()
times_heap = list()
for i in range(1, 6):
  
    xheap = data['premio_effet_anno_incorso'] 
    _subset = xheap[0 : 9000*i]
    arr = np.array(_subset)
    list_heap = arr.tolist()
    start = time.time()
    heapSort(list_heap)
    end = time.time()
  
    print(len(list_heap), "Elements Sorted by HeapSort in ", end-start)
    elements_heap.append(len(list_heap))
    times_heap.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by HeapSort in  0.16907143592834473
# 18000 Elements Sorted by HeapSort in  0.6402003765106201
# 27000 Elements Sorted by HeapSort in  1.4491822719573975
# 36000 Elements Sorted by HeapSort in  2.543363094329834
# 45000 Elements Sorted by HeapSort in  3.904449224472046

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 45mila elementi

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick, times_quick, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.plot(elements_inse, times_inse, label ='InsertionSort',color = 'b')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## confronto tra algoritmi specifici

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.plot(elements_inse, times_inse, label ='InsertionSort')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.subplot(132)
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort', color = 'g')
plt.plot(elements_quick, times_quick, label ='QuickSort',color = 'brown')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record non ordinati su numeri interi
# ### test su 20mila elementi

# %%
#MERGE
elements_merge20k = list()
times_merge20k = list()
for i in range(1, 5):
  
    xmerge = data['premio_effet_anno_incorso'] 
    _subset = xmerge[0 : 5000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge20k.append(len(list_merge))
    times_merge20k.append(end-start)
# Out:
# 5000 Elements Sorted by MergeSort in  0.01994633674621582
# 10000 Elements Sorted by MergeSort in  0.0449070930480957
# 15000 Elements Sorted by MergeSort in  0.06685543060302734
# 20000 Elements Sorted by MergeSort in  0.08975982666015625

# %%
#BUBBLE
elements_bubble20k = list()
times_bubble20k = list()
for i in range(1, 5):
  
    xbubble = data['premio_effet_anno_incorso'] 
    _subset = xbubble[0 : 5000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble20k.append(len(list_bubble))
    times_bubble20k.append(end-start)
# Out:
# 5000 Elements Sorted by BubbleSort in  2.08135724067688
# 10000 Elements Sorted by BubbleSort in  8.191778421401978
# 15000 Elements Sorted by BubbleSort in  19.932002305984497
# 20000 Elements Sorted by BubbleSort in  35.38168287277222

# %%
#INSERTION
elements_inse20k = list()
times_inse20k = list()
for i in range(1, 5):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 5000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse20k.append(len(list_inse))
    times_inse20k.append(end-start)
# Out:
# 5000 Elements Sorted by InsertionSort in  1.0546565055847168
# 10000 Elements Sorted by InsertionSort in  4.008496999740601
# 15000 Elements Sorted by InsertionSort in  9.152732133865356
# 20000 Elements Sorted by InsertionSort in  15.80249834060669

# %%
#QUICK
elements_quick20k = list()
times_quick20k = list()
for i in range(1, 5):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 5000*i]
    arr = np.array(_subset)
    list_quick = arr.tolist()
    start = time.time()
    quickSort(list_quick)
    end = time.time()
  
    print(len(list_quick), "Elements Sorted by QuickSort in ", end-start)
    elements_quick20k.append(len(list_quick))
    times_quick20k.append(end-start)
# Out:
# 5000 Elements Sorted by QuickSort in  0.0009963512420654297
# 10000 Elements Sorted by QuickSort in  0.0009970664978027344
# 15000 Elements Sorted by QuickSort in  0.0019960403442382812
# 20000 Elements Sorted by QuickSort in  0.003470182418823242

# %%
#HEAP
elements_heap20k = list()
times_heap20k = list()
for i in range(1, 5):
  
    xheap = data['premio_effet_anno_incorso'] 
    _subset = xheap[0 : 5000*i]
    arr = np.array(_subset)
    list_heap = arr.tolist()
    start = time.time()
    heapSort(list_heap)
    end = time.time()
  
    print(len(list_heap), "Elements Sorted by HeapSort in ", end-start)
    elements_heap20k.append(len(list_heap))
    times_heap20k.append(end-start)
# Out:
# 5000 Elements Sorted by HeapSort in  0.06732869148254395
# 10000 Elements Sorted by HeapSort in  0.21542572975158691
# 15000 Elements Sorted by HeapSort in  0.47817492485046387
# 20000 Elements Sorted by HeapSort in  0.846848726272583

# %% [markdown]
# ## Grafici: singoli e comparati
# ### test su 20mila elementi

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge20k, times_merge20k, label ='MergeSort', color = 'g')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('HeapSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_heap20k, times_heap20k, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse20k, times_inse20k, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble20k, times_bubble20k, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 8))
plt.title('QuickSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick20k, times_quick20k, label ='QuickSort', color = 'brown')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick20k, times_quick20k, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble20k, times_bubble20k, label ='BubbleSort',color = 'r')
plt.plot(elements_inse20k, times_inse20k, label ='InsertionSort',color = 'b')
plt.plot(elements_merge20k, times_merge20k, label ='MergeSort',color = 'g')
plt.plot(elements_heap20k, times_heap20k, label ='HeapSort',color = 'orange')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record non ordinati su numeri interi
# ### test su 8mila elementi

# %%
#MERGE
elements_merge8k = list()
times_merge8k = list()
for i in range(1, 9):
  
    xmerge = data['premio_effet_anno_incorso'] 
    _subset = xmerge[0 : 1000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge8k.append(len(list_merge))
    times_merge8k.append(end-start)
# Out:
# 1000 Elements Sorted by MergeSort in  0.0029909610748291016
# 2000 Elements Sorted by MergeSort in  0.0069806575775146484
# 3000 Elements Sorted by MergeSort in  0.012268781661987305
# 4000 Elements Sorted by MergeSort in  0.015954971313476562
# 5000 Elements Sorted by MergeSort in  0.01894855499267578
# 6000 Elements Sorted by MergeSort in  0.022938013076782227
# 7000 Elements Sorted by MergeSort in  0.02692699432373047
# 8000 Elements Sorted by MergeSort in  0.03490400314331055

# %%
#BUBBLE
elements_bubble8k = list()
times_bubble8k = list()
for i in range(1, 9):
  
    xbubble = data['premio_effet_anno_incorso'] 
    _subset = xbubble[0 : 1000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble8k.append(len(list_bubble))
    times_bubble8k.append(end-start)
# Out:
# 1000 Elements Sorted by BubbleSort in  0.08878159523010254
# 2000 Elements Sorted by BubbleSort in  0.34115123748779297
# 3000 Elements Sorted by BubbleSort in  0.7710878849029541
# 4000 Elements Sorted by BubbleSort in  1.3914852142333984
# 5000 Elements Sorted by BubbleSort in  2.1568639278411865
# 6000 Elements Sorted by BubbleSort in  3.0508992671966553
# 7000 Elements Sorted by BubbleSort in  4.111103534698486
# 8000 Elements Sorted by BubbleSort in  5.439090251922607

# %%
#INSERTION
elements_inse8k = list()
times_inse8k = list()
for i in range(1, 9):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse8k.append(len(list_inse))
    times_inse8k.append(end-start)
# Out:
# 1000 Elements Sorted by InsertionSort in  0.04489541053771973
# 2000 Elements Sorted by InsertionSort in  0.16655421257019043
# 3000 Elements Sorted by InsertionSort in  0.37406063079833984
# 4000 Elements Sorted by InsertionSort in  0.6733231544494629
# 5000 Elements Sorted by InsertionSort in  1.071805477142334
# 6000 Elements Sorted by InsertionSort in  1.4590208530426025
# 7000 Elements Sorted by InsertionSort in  1.9447078704833984
# 8000 Elements Sorted by InsertionSort in  2.5779011249542236

# %%
#QUICK
elements_quick8k = list()
times_quick8k = list()
for i in range(1, 9):
  
    xinsertion = data['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_quick = arr.tolist()
    start = time.time()
    quickSort(list_quick)
    end = time.time()
  
    print(len(list_quick), "Elements Sorted by QuickSort in ", end-start)
    elements_quick8k.append(len(list_quick))
    times_quick8k.append(end-start)
# Out:
# 1000 Elements Sorted by QuickSort in  0.0
# 2000 Elements Sorted by QuickSort in  0.0
# 3000 Elements Sorted by QuickSort in  0.0
# 4000 Elements Sorted by QuickSort in  0.0009970664978027344
# 5000 Elements Sorted by QuickSort in  0.0009975433349609375
# 6000 Elements Sorted by QuickSort in  0.0009975433349609375
# 7000 Elements Sorted by QuickSort in  0.0009968280792236328
# 8000 Elements Sorted by QuickSort in  0.0009970664978027344

# %%
#HEAP
elements_heap8k = list()
times_heap8k = list()
for i in range(1, 9):
  
    xheap = data['premio_effet_anno_incorso'] 
    _subset = xheap[0 : 1000*i]
    arr = np.array(_subset)
    list_heap = arr.tolist()
    start = time.time()
    heapSort(list_heap)
    end = time.time()
  
    print(len(list_heap), "Elements Sorted by HeapSort in ", end-start)
    elements_heap8k.append(len(list_heap))
    times_heap8k.append(end-start)
# Out:
# 1000 Elements Sorted by HeapSort in  0.006489992141723633
# 2000 Elements Sorted by HeapSort in  0.019341230392456055
# 3000 Elements Sorted by HeapSort in  0.029428482055664062
# 4000 Elements Sorted by HeapSort in  0.045850276947021484
# 5000 Elements Sorted by HeapSort in  0.06482720375061035
# 6000 Elements Sorted by HeapSort in  0.0857386589050293
# 7000 Elements Sorted by HeapSort in  0.11469101905822754
# 8000 Elements Sorted by HeapSort in  0.14860296249389648

# %% [markdown]
# ## Grafici: singoli e comparati
# ### test su 8mila elementi

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort', color = 'g')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('HeapSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_heap8k, times_heap8k, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('QuickSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8k, times_quick8k, label ='QuickSort', color = 'brown')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8k, times_quick8k, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort',color = 'r')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort',color = 'b')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort',color = 'g')
plt.plot(elements_heap8k, times_heap8k, label ='HeapSort',color = 'orange')

plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8k, times_quick8k, label ='QuickSort',color = 'brown')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort',color = 'g')
plt.plot(elements_heap8k, times_heap8k, label ='HeapSort',color = 'orange')

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi

# %% [markdown]
# ## Record ordinati su numeri interi
# ### test su 45mila elementi

# %%
#MERGE
elements_mergeO = list()
times_mergeO = list()
for i in range(1, 6):
  
    xmerge = data_2['premio_effet_anno_incorso'] 
    _subset = xmerge[0 : 9000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_mergeO.append(len(list_merge))
    times_mergeO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by MergeSort in  0.033739328384399414
# 18000 Elements Sorted by MergeSort in  0.07280325889587402
# 27000 Elements Sorted by MergeSort in  0.10870909690856934
# 36000 Elements Sorted by MergeSort in  0.14759445190429688
# 45000 Elements Sorted by MergeSort in  0.18650102615356445

# %%
#BUBBLE
elements_bubbleO = list()
times_bubbleO = list()
for i in range(1, 6):
  
    xbubble = data_2['premio_effet_anno_incorso'] 
    _subset = xbubble[0 : 9000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubbleO.append(len(list_bubble))
    times_bubbleO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by BubbleSort in  3.801128387451172
# 18000 Elements Sorted by BubbleSort in  15.523222208023071
# 27000 Elements Sorted by BubbleSort in  35.1332745552063
# 36000 Elements Sorted by BubbleSort in  64.40389108657837
# 45000 Elements Sorted by BubbleSort in  97.78090119361877

# %%
#INSERTION
elements_inseO = list()
times_inseO = list()
for i in range(1, 6):
  
    xinsertion = data_2['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inseO.append(len(list_inse))
    times_inseO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by InsertionSort in  0.001995086669921875
# 18000 Elements Sorted by InsertionSort in  0.003530263900756836
# 27000 Elements Sorted by InsertionSort in  0.0060024261474609375
# 36000 Elements Sorted by InsertionSort in  0.006981849670410156
# 45000 Elements Sorted by InsertionSort in  0.009972572326660156

# %%
#QUICK
elements_quickO = list()
times_quickO = list()
for i in range(1, 6):
  
    xinsertion = data_2['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_quick = arr.tolist()
    start = time.time()
    quickSort(list_quick)
    end = time.time()
  
    print(len(list_quick), "Elements Sorted by QuickSort in ", end-start)
    elements_quickO.append(len(list_quick))
    times_quickO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quickO, times_quickO, label ='QuickSort',color = 'brown')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by QuickSort in  0.0009968280792236328
# 18000 Elements Sorted by QuickSort in  0.001995086669921875
# 27000 Elements Sorted by QuickSort in  0.0029921531677246094
# 36000 Elements Sorted by QuickSort in  0.003988027572631836
# 45000 Elements Sorted by QuickSort in  0.00598454475402832

# %%
#HEAP
elements_heapO = list()
times_heapO = list()
for i in range(1, 6):
  
    xheap = data_2['premio_effet_anno_incorso'] 
    _subset = xheap[0 : 9000*i]
    arr = np.array(_subset)
    list_heap = arr.tolist()
    start = time.time()
    heapSort(list_heap)
    end = time.time()
  
    print(len(list_heap), "Elements Sorted by HeapSort in ", end-start)
    elements_heapO.append(len(list_heap))
    times_heapO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_heapO, times_heapO, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by HeapSort in  0.17489027976989746
# 18000 Elements Sorted by HeapSort in  0.6534242630004883
# 27000 Elements Sorted by HeapSort in  1.4519023895263672
# 36000 Elements Sorted by HeapSort in  2.514125108718872
# 45000 Elements Sorted by HeapSort in  4.187521696090698

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 45mila elementi non ordinati e ordinati

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick, times_quick, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.plot(elements_inse, times_inse, label ='InsertionSort',color = 'b')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quickO, times_quickO, label ='QuickSort',color = 'brown')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort',color = 'r')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort',color = 'b')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort',color = 'g')
plt.plot(elements_heapO, times_heapO, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick, times_quick, label ='QuickSort',color = 'brown')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.plot(elements_heap, times_heap, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quickO, times_quickO, label ='QuickSort',color = 'brown')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort',color = 'b')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort',color = 'g')
plt.plot(elements_heapO, times_heapO, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 9))
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quickO, times_quickO, label ='QuickSort',color = 'brown')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record ordinati su numeri interi
# ### test su 8mila elementi

# %%
#MERGE
elements_merge8kO = list()
times_merge8kO = list()
for i in range(1, 9):
  
    xmerge = data_2['premio_effet_anno_incorso'] 
    _subset = xmerge[0 : 1000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge8kO.append(len(list_merge))
    times_merge8kO.append(end-start)
# Out:
# 1000 Elements Sorted by MergeSort in  0.0029914379119873047
# 2000 Elements Sorted by MergeSort in  0.00598454475402832
# 3000 Elements Sorted by MergeSort in  0.01148843765258789
# 4000 Elements Sorted by MergeSort in  0.01394796371459961
# 5000 Elements Sorted by MergeSort in  0.019946575164794922
# 6000 Elements Sorted by MergeSort in  0.02094411849975586
# 7000 Elements Sorted by MergeSort in  0.0249330997467041
# 8000 Elements Sorted by MergeSort in  0.028922080993652344

# %%
#BUBBLE
elements_bubble8kO = list()
times_bubble8kO = list()
for i in range(1, 9):
  
    xbubble = data_2['premio_effet_anno_incorso'] 
    _subset = xbubble[0 : 1000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble8kO.append(len(list_bubble))
    times_bubble8kO.append(end-start)
# Out:
# 1000 Elements Sorted by BubbleSort in  0.047872304916381836
# 2000 Elements Sorted by BubbleSort in  0.1759023666381836
# 3000 Elements Sorted by BubbleSort in  0.407912015914917
# 4000 Elements Sorted by BubbleSort in  0.7314894199371338
# 5000 Elements Sorted by BubbleSort in  1.1399166584014893
# 6000 Elements Sorted by BubbleSort in  1.6643249988555908
# 7000 Elements Sorted by BubbleSort in  2.2563302516937256
# 8000 Elements Sorted by BubbleSort in  3.0476179122924805

# %%
#INSERTION
elements_inse8kO = list()
times_inse8kO = list()
for i in range(1, 9):
  
    xinsertion = data_2['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse8kO.append(len(list_inse))
    times_inse8kO.append(end-start)
# Out:
# 1000 Elements Sorted by InsertionSort in  0.0
# 2000 Elements Sorted by InsertionSort in  0.0
# 3000 Elements Sorted by InsertionSort in  0.0005991458892822266
# 4000 Elements Sorted by InsertionSort in  0.0005257129669189453
# 5000 Elements Sorted by InsertionSort in  0.0005037784576416016
# 6000 Elements Sorted by InsertionSort in  0.0009965896606445312
# 7000 Elements Sorted by InsertionSort in  0.000997304916381836
# 8000 Elements Sorted by InsertionSort in  0.0015022754669189453

# %%
#QUICK
elements_quick8kO = list()
times_quick8kO = list()
for i in range(1, 9):
  
    xinsertion = data_2['premio_effet_anno_incorso'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_quick = arr.tolist()
    start = time.time()
    quickSort(list_quick)
    end = time.time()
  
    print(len(list_quick), "Elements Sorted by QuickSort in ", end-start)
    elements_quick8kO.append(len(list_quick))
    times_quick8kO.append(end-start)
# Out:
# 1000 Elements Sorted by QuickSort in  0.0
# 2000 Elements Sorted by QuickSort in  0.0
# 3000 Elements Sorted by QuickSort in  0.0
# 4000 Elements Sorted by QuickSort in  0.0011932849884033203
# 5000 Elements Sorted by QuickSort in  0.0008001327514648438
# 6000 Elements Sorted by QuickSort in  0.0009970664978027344
# 7000 Elements Sorted by QuickSort in  0.0015125274658203125
# 8000 Elements Sorted by QuickSort in  0.000990152359008789

# %%
#HEAP
elements_heap8kO = list()
times_heap8kO = list()
for i in range(1, 9):
  
    xheap = data_2['premio_effet_anno_incorso'] 
    _subset = xheap[0 : 1000*i]
    arr = np.array(_subset)
    list_heap = arr.tolist()
    start = time.time()
    heapSort(list_heap)
    end = time.time()
  
    print(len(list_heap), "Elements Sorted by HeapSort in ", end-start)
    elements_heap8kO.append(len(list_heap))
    times_heap8kO.append(end-start)
# Out:
# 1000 Elements Sorted by HeapSort in  0.006981849670410156
# 2000 Elements Sorted by HeapSort in  0.0164642333984375
# 3000 Elements Sorted by HeapSort in  0.02892279624938965
# 4000 Elements Sorted by HeapSort in  0.042885541915893555
# 5000 Elements Sorted by HeapSort in  0.06482672691345215
# 6000 Elements Sorted by HeapSort in  0.08278632164001465
# 7000 Elements Sorted by HeapSort in  0.11269760131835938
# 8000 Elements Sorted by HeapSort in  0.13816094398498535

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 8mila elementi non ordinati e ordinati

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8k, times_quick8k, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort',color = 'r')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort',color = 'b')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort',color = 'g')
plt.plot(elements_heap8k, times_heap8k, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8kO, times_quick8kO, label ='QuickSort',color = 'brown')
plt.plot(elements_bubble8kO, times_bubble8kO, label ='BubbleSort',color = 'r')
plt.plot(elements_inse8kO, times_inse8kO, label ='InsertionSort',color = 'b')
plt.plot(elements_merge8kO, times_merge8kO, label ='MergeSort',color = 'g')
plt.plot(elements_heap8kO, times_heap8kO, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8k, times_quick8k, label ='QuickSort',color = 'brown')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort',color = 'g')
plt.plot(elements_heap8k, times_heap8k, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8kO, times_quick8kO, label ='QuickSort',color = 'brown')
plt.plot(elements_inse8kO, times_inse8kO, label ='InsertionSort',color = 'b')
plt.plot(elements_merge8kO, times_merge8kO, label ='MergeSort',color = 'g')
plt.plot(elements_heap8kO, times_heap8kO, label ='HeapSort',color = 'orange')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 9))
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick8kO, times_quick8kO, label ='QuickSort',color = 'brown')
plt.plot(elements_inse8kO, times_inse8kO, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Confronto tra grafici algoritmi singoli ordinati e non

# %%
plt.figure(figsize=(11, 8))
plt.title('Contronto QuickSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_quick, times_quick, label ='QuickSort_Non_Ord',color = 'brown')
plt.plot(elements_quickO, times_quickO, label ='QuickSort_Ord')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Contronto BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort_Non_Ord',color = 'r')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort_Ord')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Contronto InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse, times_inse, label ='InsertionSort_Non_Ord',color = 'b')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort_Ord')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Contronto MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort_Non_Ord',color = 'g')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort_Ord')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Contronto HeapSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_heap, times_heap, label ='HeapSort_Non_Ord',color = 'orange')
plt.plot(elements_heapO, times_heapO, label ='HeapSort_Ord')
plt.grid()
plt.legend()
plt.show()
