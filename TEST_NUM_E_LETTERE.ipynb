# %% [markdown]
# # PER IL CORRETTO FUNZIONAMENTO DEL CODICE:

# %% [markdown]
# # Librerie usate

# %%
import time
from numpy.random import seed
from numpy.random import randint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Visualizazione Dataset

# %%
data = pd.read_csv("dataset.csv")
data
# Out:
#        premio_effet_anno_incorso  eta_polizza bonus_malus
# 0                     1951.40000            3          11
# 1                      265.46190            9          1F
# 2                      276.84340           10          1G
# 3                      289.58118            6          1H
# 4                      173.86400           24          1F
# ...                          ...          ...         ...
# 45386                  239.41000           32          1G
# 45387                  250.79000           33          1H
# 45388                  350.39570            8          1F
# 45389                  364.18740            9          1G
# 45390                  382.51016            6          1H
#
# [45391 rows x 3 columns]

# %%
data_2 = pd.read_csv("dataset.csv")
data_2.sort_values(by=['bonus_malus'], ascending = True, inplace = True)
data_2
# Out:
#        premio_effet_anno_incorso  eta_polizza bonus_malus
# 20049                  497.86108            5          01
# 18635                  431.52000           11          01
# 38637                  732.99786            2          01
# 3396                   310.49350            6          01
# 3397                   318.66640            6          01
# ...                          ...          ...         ...
# 8922                   287.16302           17          1H
# 1383                   437.11920            7          1H
# 45390                  382.51016            6          1H
# 44866                  194.17000            5          FR
# 33608                   93.90000            1          FR
#
# [45391 rows x 3 columns]

# %% [markdown]
# # FUNZIONI

# %% [markdown]
# funzioni algoritmi

# %%
def insertionSort(arr):
    # Scorri da 1 a  len(arr)#
    for i in range(1, len(arr)):
        
  
        key = arr[i]
  
        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key
        
def bubbleSort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n-1):
    # range(n) also work but outer loop will repeat one time more than needed.
        # Last i elements are already in place
        for j in range(0, n-i-1):
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]

def mergeSort(myList):
    if len(myList) > 1:
        mid = len(myList) // 2
        left = myList[:mid]
        right = myList[mid:]

        # Recursive call on each half
        mergeSort(left)
        mergeSort(right)

        # Two iterators for traversing the two halves
        i = 0
        j = 0

        # Iterator for the main list
        k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
              # The value from the left half has been used
              myList[k] = left[i]
              # Move the iterator forward
              i += 1
            else:
                myList[k] = right[j]
                j += 1
            # Move to the next slot
            k += 1
            #per tutti i resto dei numeri 
        while i < len(left):
            myList[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            myList[k]=right[j]
            j += 1
            k += 1

# %% [markdown]
# # Dimostrazione ordinamento

# %%
xmerge = data["bonus_malus"] 
_subset = xmerge[0 : 2000]
arr = np.array(_subset)
list_merge= arr.tolist()

mergeSort(list_merge)
record_merge = []
for i in range(len(list_merge)):
    record_merge.append("%s" %list_merge[i])
with open("record_ordinati_merge_NUM_E_LETT.txt", "w") as file:
    file.write(str(record_merge))

# %%
xins = data["bonus_malus"] 
_subset = xins[0 : 2000]
arr = np.array(_subset)
list_ins= arr.tolist()

insertionSort(list_ins)
record_ins = []
for i in range(len(list_ins)):
    record_ins.append("%s" %list_ins[i])
with open("record_ordinati_insertion_NUM_E_LETT.txt", "w") as file:
    file.write(str(record_ins))

# %%
xbubble = data["bonus_malus"] 
_subset = xbubble[0 : 2000]
arr = np.array(_subset)
list_bubble= arr.tolist()

bubbleSort(list_bubble)
record_bubble = []
for i in range(len(list_bubble)):
    record_bubble.append("%s" %list_bubble[i])
with open("record_ordinati_bubble_NUM_E_LETT.txt", "w") as file:
    file.write(str(record_bubble))

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi

# %% [markdown]
# ## Record non ordinati su numeri interi
# ### test su 45mila elementi

# %%
#MERGE
elements_merge = list()
times_merge = list()
for i in range(1, 6):
  
    xmerge = data['bonus_malus'] 
    _subset = xmerge[0 : 9000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge.append(len(list_merge))
    times_merge.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by MergeSort in  0.039895057678222656
# 18000 Elements Sorted by MergeSort in  0.08028173446655273
# 27000 Elements Sorted by MergeSort in  0.1246647834777832
# 36000 Elements Sorted by MergeSort in  0.17553091049194336
# 45000 Elements Sorted by MergeSort in  0.2184145450592041

# %%
#BUBBLE
elements_bubble = list()
times_bubble = list()
for i in range(1, 6):
  
    xbubble = data['bonus_malus'] 
    _subset = xbubble[0 : 9000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble.append(len(list_bubble))
    times_bubble.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by BubbleSort in  6.858853816986084
# 18000 Elements Sorted by BubbleSort in  27.84445834159851
# 27000 Elements Sorted by BubbleSort in  63.57007384300232
# 36000 Elements Sorted by BubbleSort in  113.26238775253296
# 45000 Elements Sorted by BubbleSort in  177.8681046962738

# %%
#INSERTION
elements_inse = list()
times_inse = list()
for i in range(1, 6):
  
    xinsertion = data['bonus_malus'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse.append(len(list_inse))
    times_inse.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse, times_inse, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by InsertionSort in  3.2043967247009277
# 18000 Elements Sorted by InsertionSort in  12.973994731903076
# 27000 Elements Sorted by InsertionSort in  30.688328742980957
# 36000 Elements Sorted by InsertionSort in  55.81780648231506
# 45000 Elements Sorted by InsertionSort in  93.03339433670044

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 45mila elementi

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort',color = 'r')
plt.plot(elements_inse, times_inse, label ='InsertionSort',color = 'b')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record non ordinati su numeri interi
# ### test su 20mila elementi

# %%
#MERGE
elements_merge20k = list()
times_merge20k = list()
for i in range(1, 5):
  
    xmerge = data['bonus_malus'] 
    _subset = xmerge[0 : 5000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge20k.append(len(list_merge))
    times_merge20k.append(end-start)
# Out:
# 5000 Elements Sorted by MergeSort in  0.021939754486083984
# 10000 Elements Sorted by MergeSort in  0.042173147201538086
# 15000 Elements Sorted by MergeSort in  0.06981277465820312
# 20000 Elements Sorted by MergeSort in  0.09474039077758789

# %%
#BUBBLE
elements_bubble20k = list()
times_bubble20k = list()
for i in range(1, 5):
  
    xbubble = data['bonus_malus'] 
    _subset = xbubble[0 : 5000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble20k.append(len(list_bubble))
    times_bubble20k.append(end-start)
# Out:
# 5000 Elements Sorted by BubbleSort in  2.021061658859253
# 10000 Elements Sorted by BubbleSort in  8.408047676086426
# 15000 Elements Sorted by BubbleSort in  19.323440551757812
# 20000 Elements Sorted by BubbleSort in  33.63291668891907

# %%
#INSERTION
elements_inse20k = list()
times_inse20k = list()
for i in range(1, 5):
  
    xinsertion = data['bonus_malus'] 
    _subset = xinsertion[0 : 5000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse20k.append(len(list_inse))
    times_inse20k.append(end-start)
# Out:
# 5000 Elements Sorted by InsertionSort in  0.9252595901489258
# 10000 Elements Sorted by InsertionSort in  4.017127752304077
# 15000 Elements Sorted by InsertionSort in  9.26253628730774
# 20000 Elements Sorted by InsertionSort in  16.93362307548523

# %% [markdown]
# ## Grafici: singoli e comparati
# ### test su 20mila elementi

# %%
plt.figure(figsize=(11, 8))
plt.title('MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge20k, times_merge20k, label ='MergeSort', color = 'g')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse20k, times_inse20k, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble20k, times_bubble20k, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble20k, times_bubble20k, label ='BubbleSort',color = 'r')
plt.plot(elements_inse20k, times_inse20k, label ='InsertionSort',color = 'b')
plt.plot(elements_merge20k, times_merge20k, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record non ordinati su numeri interi
# ### test su 8mila elementi

# %%
#MERGE
elements_merge8k = list()
times_merge8k = list()
for i in range(1, 9):
  
    xmerge = data['bonus_malus'] 
    _subset = xmerge[0 : 1000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge8k.append(len(list_merge))
    times_merge8k.append(end-start)
# Out:
# 1000 Elements Sorted by MergeSort in  0.0029931068420410156
# 2000 Elements Sorted by MergeSort in  0.007982969284057617
# 3000 Elements Sorted by MergeSort in  0.011356592178344727
# 4000 Elements Sorted by MergeSort in  0.015952110290527344
# 5000 Elements Sorted by MergeSort in  0.01997518539428711
# 6000 Elements Sorted by MergeSort in  0.026898622512817383
# 7000 Elements Sorted by MergeSort in  0.02892470359802246
# 8000 Elements Sorted by MergeSort in  0.03291177749633789

# %%
#BUBBLE
elements_bubble8k = list()
times_bubble8k = list()
for i in range(1, 9):
  
    xbubble = data['bonus_malus'] 
    _subset = xbubble[0 : 1000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble8k.append(len(list_bubble))
    times_bubble8k.append(end-start)
# Out:
# 1000 Elements Sorted by BubbleSort in  0.08191561698913574
# 2000 Elements Sorted by BubbleSort in  0.3166615962982178
# 3000 Elements Sorted by BubbleSort in  0.7065339088439941
# 4000 Elements Sorted by BubbleSort in  1.2490458488464355
# 5000 Elements Sorted by BubbleSort in  2.0021331310272217
# 6000 Elements Sorted by BubbleSort in  2.82413911819458
# 7000 Elements Sorted by BubbleSort in  3.86942458152771
# 8000 Elements Sorted by BubbleSort in  5.111561298370361

# %%
#INSERTION
elements_inse8k = list()
times_inse8k = list()
for i in range(1, 9):
  
    xinsertion = data['bonus_malus'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse8k.append(len(list_inse))
    times_inse8k.append(end-start)
# Out:
# 1000 Elements Sorted by InsertionSort in  0.034924983978271484
# 2000 Elements Sorted by InsertionSort in  0.14895343780517578
# 3000 Elements Sorted by InsertionSort in  0.33078980445861816
# 4000 Elements Sorted by InsertionSort in  0.61250901222229
# 5000 Elements Sorted by InsertionSort in  0.9204375743865967
# 6000 Elements Sorted by InsertionSort in  1.2945106029510498
# 7000 Elements Sorted by InsertionSort in  1.8347725868225098
# 8000 Elements Sorted by InsertionSort in  2.376272201538086

# %% [markdown]
# ## Grafici: singoli e comparati
# ### test su 8mila elementi

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort', color = 'g')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.subplot(132)
plt.title('BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort',color = 'r')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort',color = 'b')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi

# %% [markdown]
# ## Record ordinati su numeri interi
# ### test su 45mila elementi

# %%
#MERGE
elements_mergeO = list()
times_mergeO = list()
for i in range(1, 6):
  
    xmerge = data_2['bonus_malus'] 
    _subset = xmerge[0 : 9000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_mergeO.append(len(list_merge))
    times_mergeO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by MergeSort in  0.04185962677001953
# 18000 Elements Sorted by MergeSort in  0.05839991569519043
# 27000 Elements Sorted by MergeSort in  0.10028576850891113
# 36000 Elements Sorted by MergeSort in  0.13157200813293457
# 45000 Elements Sorted by MergeSort in  0.1554243564605713

# %%
#BUBBLE
elements_bubbleO = list()
times_bubbleO = list()
for i in range(1, 6):
  
    xbubble = data_2['bonus_malus'] 
    _subset = xbubble[0 : 9000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubbleO.append(len(list_bubble))
    times_bubbleO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort',color = 'r')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by BubbleSort in  3.2336435317993164
# 18000 Elements Sorted by BubbleSort in  12.565427303314209
# 27000 Elements Sorted by BubbleSort in  29.199177503585815
# 36000 Elements Sorted by BubbleSort in  50.965227365493774
# 45000 Elements Sorted by BubbleSort in  81.68645548820496

# %%
#INSERTION
elements_inseO = list()
times_inseO = list()
for i in range(1, 6):
  
    xinsertion = data_2['bonus_malus'] 
    _subset = xinsertion[0 : 9000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inseO.append(len(list_inse))
    times_inseO.append(end-start)

    
plt.figure(figsize=(11,8))
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort',color = 'b')
plt.grid()
plt.legend()
plt.show()
# Out:
# 9000 Elements Sorted by InsertionSort in  0.0
# 18000 Elements Sorted by InsertionSort in  0.0
# 27000 Elements Sorted by InsertionSort in  0.002035379409790039
# 36000 Elements Sorted by InsertionSort in  0.011775970458984375
# 45000 Elements Sorted by InsertionSort in  0.006842374801635742

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 45mila elementi non ordinati e ordinati

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort_Non_Ord',color = 'r')
plt.plot(elements_inse, times_inse, label ='InsertionSort_Non_Ord',color = 'b')
plt.plot(elements_merge, times_merge, label ='MergeSort_Non_Ord',color = 'g')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort_Ord',color = 'r')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort_Ord',color = 'b')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort_Ord',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort',color = 'g')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort_Ord',color = 'b')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort_Ord',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Grafici tempo esecuzione singoli algoritmi
# ## Record ordinati su numeri interi
# ### test su 8mila elementi

# %%
#MERGE
elements_merge8kO = list()
times_merge8kO = list()
for i in range(1, 9):
  
    xmerge = data_2['bonus_malus'] 
    _subset = xmerge[0 : 1000*i]
    arr = np.array(_subset)
    list_merge = arr.tolist()
    start = time.time()
    mergeSort(list_merge)
    end = time.time()
  
    print(len(list_merge), "Elements Sorted by MergeSort in ", end-start)
    elements_merge8kO.append(len(list_merge))
    times_merge8kO.append(end-start)
# Out:
# 1000 Elements Sorted by MergeSort in  0.0
# 2000 Elements Sorted by MergeSort in  0.008607864379882812
# 3000 Elements Sorted by MergeSort in  0.004033327102661133
# 4000 Elements Sorted by MergeSort in  0.015624046325683594
# 5000 Elements Sorted by MergeSort in  0.015620946884155273
# 6000 Elements Sorted by MergeSort in  0.015647411346435547
# 7000 Elements Sorted by MergeSort in  0.024187088012695312
# 8000 Elements Sorted by MergeSort in  0.015590667724609375

# %%
#BUBBLE
elements_bubble8kO = list()
times_bubble8kO = list()
for i in range(1, 9):
  
    xbubble = data_2['bonus_malus'] 
    _subset = xbubble[0 : 1000*i]
    arr = np.array(_subset)
    list_bubble = arr.tolist()
    start = time.time()
    bubbleSort(list_bubble)
    end = time.time()
  
    print(len(list_bubble), "Elements Sorted by BubbleSort in ", end-start)
    elements_bubble8kO.append(len(list_bubble))
    times_bubble8kO.append(end-start)
# Out:
# 1000 Elements Sorted by BubbleSort in  0.03767991065979004
# 2000 Elements Sorted by BubbleSort in  0.1468350887298584
# 3000 Elements Sorted by BubbleSort in  0.34764742851257324
# 4000 Elements Sorted by BubbleSort in  0.6181564331054688
# 5000 Elements Sorted by BubbleSort in  1.001049518585205
# 6000 Elements Sorted by BubbleSort in  1.4480628967285156
# 7000 Elements Sorted by BubbleSort in  1.9520413875579834
# 8000 Elements Sorted by BubbleSort in  2.5616636276245117

# %%
#INSERTION
elements_inse8kO = list()
times_inse8kO = list()
for i in range(1, 9):
  
    xinsertion = data_2['bonus_malus'] 
    _subset = xinsertion[0 : 1000*i]
    arr = np.array(_subset)
    list_inse = arr.tolist()
    start = time.time()
    insertionSort(list_inse)
    end = time.time()
  
    print(len(list_inse), "Elements Sorted by InsertionSort in ", end-start)
    elements_inse8kO.append(len(list_inse))
    times_inse8kO.append(end-start)
# Out:
# 1000 Elements Sorted by InsertionSort in  0.0
# 2000 Elements Sorted by InsertionSort in  0.0
# 3000 Elements Sorted by InsertionSort in  0.0
# 4000 Elements Sorted by InsertionSort in  0.001016378402709961
# 5000 Elements Sorted by InsertionSort in  0.0010128021240234375
# 6000 Elements Sorted by InsertionSort in  0.0010132789611816406
# 7000 Elements Sorted by InsertionSort in  0.0010113716125488281
# 8000 Elements Sorted by InsertionSort in  0.0020232200622558594

# %% [markdown]
# ## Confronto di tutti gli algoritmi
# ### test con 8mila elementi non ordinati e ordinati

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Grafici con dataset non ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble8k, times_bubble8k, label ='BubbleSort_Non_Ord',color = 'r')
plt.plot(elements_inse8k, times_inse8k, label ='InsertionSort_Non_Ord',color = 'b')
plt.plot(elements_merge8k, times_merge8k, label ='MergeSort_Non_Ord',color = 'g')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble8kO, times_bubble8kO, label ='BubbleSort_Ord',color = 'r')
plt.plot(elements_inse8kO, times_inse8kO, label ='InsertionSort_Ord',color = 'b')
plt.plot(elements_merge8kO, times_merge8kO, label ='MergeSort_Ord',color = 'g')
plt.grid()
plt.legend()
plt.subplot(133)
plt.title('Grafici con dataset ordinato')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse8kO, times_inse8kO, label ='InsertionSort_Ord',color = 'b')
plt.plot(elements_merge8kO, times_merge8kO, label ='MergeSort_Ord',color = 'g')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Confronto tra grafici algoritmi singoli ordinati e non

# %%
plt.figure(figsize=(25, 9))
plt.subplot(131)
plt.title('Contronto BubbleSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_bubble, times_bubble, label ='BubbleSort_Non_Ord',color = 'r')
plt.plot(elements_bubbleO, times_bubbleO, label ='BubbleSort_Ord')
plt.grid()
plt.legend()

plt.subplot(132)
plt.title('Contronto InsertionSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_inse, times_inse, label ='InsertionSort_Non_Ord',color = 'b')
plt.plot(elements_inseO, times_inseO, label ='InsertionSort_Ord')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 8))
plt.title('Confronto MergeSort')
plt.xlabel('Numero Elementi')
plt.ylabel('Tempo')
plt.plot(elements_merge, times_merge, label ='MergeSort_Non_Ord',color = 'g')
plt.plot(elements_mergeO, times_mergeO, label ='MergeSort_Ord')
plt.grid()
plt.legend()
plt.show()
